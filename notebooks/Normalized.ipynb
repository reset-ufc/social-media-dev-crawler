# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\K\social-media-dev-crawler\data\Lda\normalized_posts.csv')

# %%
df['normalized_text'].head()
# Out:
# 0    rfc defines suggested multiple place set still...
# 1    using ethereum keystore file format encrypt da...
# 2    nist sp specifies correspondence rsa modulus s...
# 3    background making program fun learning exercis...
# 4    may sound stupid many would like pointer exact...
# Name: normalized_text, dtype: object
