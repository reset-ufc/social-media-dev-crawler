# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('C:\K\social-media-dev-crawler\data\preprocessed_full_posts.csv')
df.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\K'
# <>:4: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\RESET Lab\AppData\Local\Temp\ipykernel_16892\1310106613.py:4: SyntaxWarning: invalid escape sequence '\K'
#   df = pd.read_csv('C:\K\social-media-dev-crawler\data\preprocessed_full_posts.csv')
#                     site_alias                                  tags  \
# 0  crypto.stackexchange.com.7z                   passwords;hash;salt
# 1  crypto.stackexchange.com.7z         cryptanalysis;file-encryption
# 2  crypto.stackexchange.com.7z  symmetric;encryption;hash;public-key
# 3  crypto.stackexchange.com.7z                rsa;cpu;implementation
# 4  crypto.stackexchange.com.7z  cryptanalysis;key-reuse;one-time-pad
#
#    question_id  accepted_answer_id  answer_count            creation_date  \
# 0        12795             12817.0           2.0  2014-01-08T23:01:58.563
# 1        72384                 NaN           7.0  2019-08-05T11:28:18.697
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4386 entries, 0 to 4385
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   site_alias          4386 non-null   object
#  1   tags                284 non-null    object
#  2   question_id         4386 non-null   int64
#  3   accepted_answer_id  204 non-null    float64
#  4   answer_count        4386 non-null   float64
#  5   creation_date       4386 non-null   object
#  6   last_activity_date  1706 non-null   object
#  7   last_edit_date      905 non-null    object
#  8   owner_id            4197 non-null   float64
#  9   score               4386 non-null   float64
#  10  view_count          4386 non-null   float64
#  11  comment_count       4386 non-null   float64
#  12  title               284 non-null    object
#  13  body                4386 non-null   object
#  14  site                4386 non-null   object
# ...

# %%
questions = df[df['type'] == 'question']
answers = df[df['type'] == 'answer']

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 284 entries, 0 to 283
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   site_alias          284 non-null    object
#  1   tags                284 non-null    object
#  2   question_id         284 non-null    int64
#  3   accepted_answer_id  204 non-null    float64
#  4   answer_count        284 non-null    float64
#  5   creation_date       284 non-null    object
#  6   last_activity_date  284 non-null    object
#  7   last_edit_date      241 non-null    object
#  8   owner_id            273 non-null    float64
#  9   score               284 non-null    float64
#  10  view_count          284 non-null    float64
#  11  comment_count       284 non-null    float64
#  12  title               284 non-null    object
#  13  body                284 non-null    object
#  14  site                284 non-null    object
# ...

# %%
answers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1422 entries, 284 to 2515
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   site_alias          1422 non-null   object
#  1   tags                0 non-null      object
#  2   question_id         1422 non-null   int64
#  3   accepted_answer_id  0 non-null      float64
#  4   answer_count        1422 non-null   float64
#  5   creation_date       1422 non-null   object
#  6   last_activity_date  1422 non-null   object
#  7   last_edit_date      664 non-null    object
#  8   owner_id            1371 non-null   float64
#  9   score               1422 non-null   float64
#  10  view_count          1422 non-null   float64
#  11  comment_count       1422 non-null   float64
#  12  title               0 non-null      object
#  13  body                1422 non-null   object
#  14  site                1422 non-null   object
# ...

# %%
na_q = questions[pd.isna(questions['code'])]
na_q.head()
# Out:
#                     site_alias  \
# 1  crypto.stackexchange.com.7z
# 2  crypto.stackexchange.com.7z
# 3  crypto.stackexchange.com.7z
# 4  crypto.stackexchange.com.7z
# 7  crypto.stackexchange.com.7z
#
#                                                 tags  question_id  \
# 1                      cryptanalysis;file-encryption        72384
# 2               symmetric;encryption;hash;public-key         5861
# 3                             rsa;cpu;implementation        35586
# 4               cryptanalysis;key-reuse;one-time-pad         2249
# 7  random-number-generator;randomness;pseudo-rand...        87978
#
#    accepted_answer_id  answer_count            creation_date  \
# 1                 NaN           7.0  2019-08-05T11:28:18.697
# 2              5863.0           2.0  2012-12-30T16:57:14.387
# 3             35594.0           5.0  2016-05-26T08:55:11.900
# 4              2250.0           3.0  2012-03-31T22:29:02.540
# 7                 NaN           8.0  2021-02-04T02:21:43.363
#
# ...
