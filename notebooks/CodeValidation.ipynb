# %% [markdown]
# ## Valid

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('C:\K\social-media-dev-crawler\data\data_mining\s2\preprocessed_full_posts.csv')
df.head()
# Out:
#   site_alias                                               tags  question_id  \
# 0     crypto  ciphertext-only-attack;one-time-pad;xor;key-reuse        88430
# 1     crypto                               chacha;stream-cipher        70094
# 2     crypto                             ctr;aes;cryptocurrency        55014
# 3     crypto            passwords;cryptanalysis;protocol-design         2945
# 4     crypto                            multiple-encryption;xor        27596
#
#    accepted_answer_id  answer_count            creation_date  \
# 0             88496.0           2.0  2021-02-23T10:52:00.590
# 1             70112.0           3.0  2019-04-26T22:37:10.927
# 2             55044.0           2.0  2018-01-25T15:33:08.797
# 3              2960.0           3.0  2012-06-17T21:41:57.540
# 4             27598.0           3.0  2015-08-20T08:42:52.283
#
#         last_activity_date           last_edit_date  owner_id  score  \
# 0  2024-11-14T19:00:56.130  2021-02-26T14:25:04.713    3941.0      4
# 1  2019-05-14T01:54:29.397  2021-10-07T07:59:29.080   28046.0      6
# 2  2018-01-30T15:51:38.750  2018-01-26T11:07:05.477   55389.0      4
# 3  2019-12-29T20:07:21.180                      NaN    2288.0     30
# 4  2015-08-21T01:27:09.720  2017-04-13T12:48:22.170   16353.0      8
#
#    view_count  comment_count  \
# 0     18093.0           10.0
# 1      4432.0            4.0
# 2     19846.0            5.0
# 3      3397.0            7.0
# 4      3108.0            6.0
#
#                                                title  \
# 0  How to decrypt two images encrypted using XOR ...
# 1  Does ChaCha20 counter actually increment throu...
# 2  How insecure is AES-128-CTR to encrypt any kin...
# 3        Is this password migration strategy secure?
# 4      Combining several symmetric ciphers using XOR
#
#                                                 body  \
# 0  I am trying to solve the following puzzle from...
# 1  RFC defines:\n\n<code>state = constants | key ...
# 2  I am using the Ethereum keystore file format t...
# 3  I want to upgrade the security of some existin...
# 4  I have seen a talk by Rüdiger Weis, where he s...
#
#                           site     id      type  \
# 0  crypto.stackexchange.com.7z  88430  question
# 1  crypto.stackexchange.com.7z  70094  question
# 2  crypto.stackexchange.com.7z  55014  question
# 3  crypto.stackexchange.com.7z   2945  question
# 4  crypto.stackexchange.com.7z  27596  question
#
#                                                 code
# 0  <code>from binascii import unhexlify\n\nwith o...
# 1  <code>state = constants | key | counter | nonc...
# 2  <code>MY_PASSWORD = "VeryDifficultPasword43213...
# 3  <code> MD5(salt + password)\n</code>\n\n<code>...
# 4  <code>ciphertext = twofish(message) XOR aes(me...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 486 entries, 0 to 485
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   site_alias          486 non-null    object
#  1   tags                18 non-null     object
#  2   question_id         486 non-null    int64
#  3   accepted_answer_id  14 non-null     float64
#  4   answer_count        486 non-null    float64
#  5   creation_date       486 non-null    object
#  6   last_activity_date  98 non-null     object
#  7   last_edit_date      57 non-null     object
#  8   owner_id            466 non-null    float64
#  9   score               486 non-null    int64
#  10  view_count          486 non-null    float64
#  11  comment_count       486 non-null    float64
#  12  title               18 non-null     object
#  13  body                486 non-null    object
#  14  site                486 non-null    object
#  15  id                  486 non-null    int64
#  16  type                486 non-null    object
#  17  code                31 non-null     object
# dtypes: float64(5), int64(3), object(10)
# memory usage: 68.5+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (486, 18)

# %%
questions = df[df['type'] == 'question']
answers = df[df['type'] == 'answer']

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 0 to 198
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   site_alias          18 non-null     object
#  1   tags                18 non-null     object
#  2   question_id         18 non-null     int64
#  3   accepted_answer_id  14 non-null     float64
#  4   answer_count        18 non-null     float64
#  5   creation_date       18 non-null     object
#  6   last_activity_date  18 non-null     object
#  7   last_edit_date      14 non-null     object
#  8   owner_id            17 non-null     float64
#  9   score               18 non-null     int64
#  10  view_count          18 non-null     float64
#  11  comment_count       18 non-null     float64
#  12  title               18 non-null     object
#  13  body                18 non-null     object
#  14  site                18 non-null     object
#  15  id                  18 non-null     int64
#  16  type                18 non-null     object
#  17  code                18 non-null     object
# dtypes: float64(5), int64(3), object(10)
# memory usage: 2.7+ KB

# %%
questions.iloc[9]['code']
# Out:
# '<code>#include &lt;openssl/sha.h&gt;\n\nstruct sha_crypt_state {\n    unsigned char digest[SHA256_DIGEST_LENGTH];\n};\n\nvoid sha_crypt_set_key( sha_crypt_state *state, unsigned char *key, int key_length )\n{\n    SHA256( key, key_length, state-&gt;digest );\n}\n\nvoid sha_crypt( sha_crypt_state *state, unsigned char *block )\n{\n    sha_crypt_state temp;\n    SHA256( state-&gt;digest, sizeof(state-&gt;digest), temp.digest );\n    memcpy( state-&gt;digest, temp.digest, sizeof(temp.digest) );\n\n    for ( int i = 0; i &lt; sizeof(state-&gt;digest); ++i ) {\n        block[i] ^= state-&gt;digest[i];\n    }\n}\n\nvoid sha_crypt_test()\n{\n    const char *key = "secret";\n\n    // prepare a test block\n    char block[SHA256_DIGEST_LENGTH];\n    memset( block, 0, sizeof(block) );\n    strcpy( block, "Hello, testing encryption!" );\n\n    // test encrypt\n    sha_crypt_state state;\n    set_key( &amp;state, (unsigned char *)key, strlen(key) );\n    sha_crypt( &amp;state, (unsigned char *)block );\n\n    // test decrypt\n    set_key( &amp;state, (unsigned char *)key, strlen(key) );\n    sha_crypt( &amp;state, (unsigned char *)block );\n}\n</code>'

# %%
answers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80 entries, 10 to 239
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   site_alias          80 non-null     object
#  1   tags                0 non-null      object
#  2   question_id         80 non-null     int64
#  3   accepted_answer_id  0 non-null      float64
#  4   answer_count        80 non-null     float64
#  5   creation_date       80 non-null     object
#  6   last_activity_date  80 non-null     object
#  7   last_edit_date      43 non-null     object
#  8   owner_id            78 non-null     float64
#  9   score               80 non-null     int64
#  10  view_count          80 non-null     float64
#  11  comment_count       80 non-null     float64
#  12  title               0 non-null      object
#  13  body                80 non-null     object
#  14  site                80 non-null     object
#  15  id                  80 non-null     int64
#  16  type                80 non-null     object
#  17  code                13 non-null     object
# dtypes: float64(5), int64(3), object(10)
# memory usage: 11.9+ KB

# %%
p = df[(df['question_id'] == 8695) & (df['type'] == 'question')]
p
# Out:
# Empty DataFrame
# Columns: [site_alias, tags, question_id, accepted_answer_id, answer_count, creation_date, last_activity_date, last_edit_date, owner_id, score, view_count, comment_count, title, body, site, id, type, code]
# Index: []

# %%
p = df[df['question_id'] == 12378]
p
# Out:
# Empty DataFrame
# Columns: [site_alias, tags, question_id, accepted_answer_id, answer_count, creation_date, last_activity_date, last_edit_date, owner_id, score, view_count, comment_count, title, body, site, id, type, code]
# Index: []

# %% [markdown]
# ## Invalid

# %%
df = pd.read_csv(r'C:\K\social-media-dev-crawler\data\data_mining\s2\invalid_codes.csv')
df.head()
# Out:
#   site_alias                                               tags  question_id  \
# 0     crypto                      file-encryption;cryptanalysis        72384
# 1     crypto               one-time-pad;cryptanalysis;key-reuse         2249
# 2     crypto  file-encryption;rsa;signature;hash;authenticat...         8104
# 3     crypto                                    aes-gcm;aes;gcm        76177
# 4     crypto               key-size;rsa;cryptanalysis;factoring         8687
#
#    accepted_answer_id  answer_count            creation_date  \
# 0                 NaN           7.0  2019-08-05T11:28:18.697
# 1              2250.0           3.0  2012-03-31T22:29:02.540
# 2              8116.0           5.0  2013-04-24T15:51:00.203
# 3                 NaN           3.0  2019-12-03T17:23:42.200
# 4              8692.0           4.0  2013-06-11T16:36:12.377
#
#         last_activity_date           last_edit_date  owner_id  score  \
# 0  2019-08-08T01:08:37.403  2019-08-07T18:27:14.967    8532.0     18
# 1  2016-01-31T10:22:32.350  2017-04-13T12:48:24.517    1867.0     79
# 2  2018-01-31T00:56:20.663  2013-04-24T17:03:21.083    6389.0     10
# 3  2019-12-06T11:23:35.187  2019-12-04T21:03:59.350   74873.0      9
# 4  2020-11-01T07:03:19.213  2017-04-13T12:48:22.170     214.0     48
#
#    view_count  comment_count  \
# 0     23047.0           11.0
# 1     93925.0            5.0
# 2      7163.0           18.0
# 3     33754.0            6.0
# 4     38477.0            5.0
#
#                                                title  \
# 0  How to check a file was encrypted (really & co...
# 1  How does one attack a two-time pad (i.e. one t...
# 2                          Tamper-proofing log files
# 3  How to encrypt files using AES256-GCM cipher u...
# 4  Security strength of RSA in relation with the ...
#
#                                                 body  \
# 0  I would like to audit how an implementation of...
# 1  My question might appear the same as the quest...
# 2  Problem Overview\n\nI want to securely store l...
# 3  I'm struggling to implement AES256-GCM on a Li...
# 4  NIST SP 800-57 §5.6.1 p.62–64 specifies a corr...
#
#                           site     id      type code  \
# 0  crypto.stackexchange.com.7z  72384  question  NaN
# 1  crypto.stackexchange.com.7z   2249  question  NaN
# 2  crypto.stackexchange.com.7z   8104  question  NaN
# 3  crypto.stackexchange.com.7z  76177  question  NaN
# 4  crypto.stackexchange.com.7z   8687  question  NaN
#
#                                invalid_block_preview
# 0                                   <code>ent</code>
# 1                                   <code>' '</code>
# 2                        <code>2013-01-01.log</code>
# 3  <code>$ openssl aes-256-gcm\nAEAD ciphers not ...
# 4  <code>Strength  RSA modulus size\n  80        ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2611 entries, 0 to 2610
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   site_alias             2611 non-null   object
#  1   tags                   111 non-null    object
#  2   question_id            2611 non-null   int64
#  3   accepted_answer_id     79 non-null     float64
#  4   answer_count           2611 non-null   float64
#  5   creation_date          2611 non-null   object
#  6   last_activity_date     567 non-null    object
#  7   last_edit_date         294 non-null    object
#  8   owner_id               2499 non-null   float64
#  9   score                  2611 non-null   int64
#  10  view_count             2611 non-null   float64
#  11  comment_count          2611 non-null   float64
#  12  title                  111 non-null    object
#  13  body                   2611 non-null   object
#  14  site                   2611 non-null   object
#  15  id                     2611 non-null   int64
#  16  type                   2611 non-null   object
#  17  code                   59 non-null     object
#  18  invalid_block_preview  194 non-null    object
# dtypes: float64(5), int64(3), object(11)
# memory usage: 387.7+ KB

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (2611, 19)
