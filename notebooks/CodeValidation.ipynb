# %% [markdown]
# ## Valid

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('C:\K\social-media-dev-crawler\data\data_mining\s2\preprocessed_full_posts.csv')
df.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\K'
# <>:4: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\RESET Lab\AppData\Local\Temp\ipykernel_12468\277205348.py:4: SyntaxWarning: invalid escape sequence '\K'
#   df = pd.read_csv('C:\K\social-media-dev-crawler\data\data_mining\s2\preprocessed_full_posts.csv')
#                     site_alias                              tags  question_id  \
# 0  crypto.stackexchange.com.7z                           tls;rc4          853
# 1  crypto.stackexchange.com.7z               hash;passwords;salt        12795
# 2  crypto.stackexchange.com.7z     hash;passwords;authentication         3082
# 3  crypto.stackexchange.com.7z  hash;reference-request;sha-3;xof        30587
# 4  crypto.stackexchange.com.7z              chacha;stream-cipher        70094
#
#    accepted_answer_id  answer_count            creation_date  \
# 0                 NaN           7.0  2011-09-29T05:30:51.427
# 1             12817.0           2.0  2014-01-08T23:01:58.563
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1002 entries, 0 to 1001
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   site_alias          1002 non-null   object
#  1   tags                606 non-null    object
#  2   question_id         1002 non-null   int64
#  3   accepted_answer_id  442 non-null    float64
#  4   answer_count        1002 non-null   float64
#  5   creation_date       1002 non-null   object
#  6   last_activity_date  1002 non-null   object
#  7   last_edit_date      756 non-null    object
#  8   owner_id            967 non-null    float64
#  9   score               1002 non-null   float64
#  10  view_count          1002 non-null   float64
#  11  comment_count       1002 non-null   float64
#  12  title               606 non-null    object
#  13  body                1002 non-null   object
#  14  site                1002 non-null   object
# ...

# %%
questions = df[df['type'] == 'question']
answers = df[df['type'] == 'answer']

# %%
questions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 606 entries, 0 to 605
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   site_alias          606 non-null    object
#  1   tags                606 non-null    object
#  2   question_id         606 non-null    int64
#  3   accepted_answer_id  442 non-null    float64
#  4   answer_count        606 non-null    float64
#  5   creation_date       606 non-null    object
#  6   last_activity_date  606 non-null    object
#  7   last_edit_date      512 non-null    object
#  8   owner_id            583 non-null    float64
#  9   score               606 non-null    float64
#  10  view_count          606 non-null    float64
#  11  comment_count       606 non-null    float64
#  12  title               606 non-null    object
#  13  body                606 non-null    object
#  14  site                606 non-null    object
# ...

# %%
answers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 396 entries, 606 to 1001
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   site_alias          396 non-null    object
#  1   tags                0 non-null      object
#  2   question_id         396 non-null    int64
#  3   accepted_answer_id  0 non-null      float64
#  4   answer_count        396 non-null    float64
#  5   creation_date       396 non-null    object
#  6   last_activity_date  396 non-null    object
#  7   last_edit_date      244 non-null    object
#  8   owner_id            384 non-null    float64
#  9   score               396 non-null    float64
#  10  view_count          396 non-null    float64
#  11  comment_count       396 non-null    float64
#  12  title               0 non-null      object
#  13  body                396 non-null    object
#  14  site                396 non-null    object
# ...

# %% [markdown]
# ## Invalid

# %%
df = pd.read_csv(r'C:\K\social-media-dev-crawler\data\data_mining\s2\invalid_codes.csv')
df.head()
# Out:
#                     site_alias  \
# 0  crypto.stackexchange.com.7z
# 1  crypto.stackexchange.com.7z
# 2  crypto.stackexchange.com.7z
# 3  crypto.stackexchange.com.7z
# 4  crypto.stackexchange.com.7z
#
#                                                 tags  question_id  \
# 0                      file-encryption;cryptanalysis        72384
# 1               public-key;hash;encryption;symmetric         5861
# 2                             rsa;implementation;cpu        35586
# 3               key-reuse;one-time-pad;cryptanalysis         2249
# 4  elliptic-curves;diffie-hellman;openssl;key-der...        28930
#
#    accepted_answer_id  answer_count            creation_date  \
# 0                 NaN           7.0  2019-08-05T11:28:18.697
# 1              5863.0           2.0  2012-12-30T16:57:14.387
# 2             35594.0           5.0  2016-05-26T08:55:11.900
# 3              2250.0           3.0  2012-03-31T22:29:02.540
# 4             28936.0           2.0  2015-09-04T04:40:10.110
#
# ...
