# %%
import pandas as pd

# %%
df = pd.read_json('C:\K\social-media-dev-crawler\data\llm_inference\misuse_cases_codes.json', lines=True)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\RESET Lab\AppData\Local\Temp\ipykernel_16356\1599596764.py:1: SyntaxWarning: invalid escape sequence '\K'
#   df = pd.read_json('C:\K\social-media-dev-crawler\data\llm_inference\misuse_cases_codes.json', lines=True)

# %%
df.head()
# Out:
#    has_misuse                                            summary  \
# 0        True  The code utilizes a SHA512 hash function with ...
# 1        True  The code snippets demonstrate potential vulner...
# 2        True  The code snippet exhibits potential weaknesses...
# 3        True  The code snippets demonstrate several potentia...
# 4        True  The code exhibits several potential weaknesses...
#
#                                              misuses  post_id
# 0  [{'code_index': '1', 'category': 'WC', 'subtyp...    12795
# 1  [{'code_index': '1', 'category': 'WC', 'subtyp...    28930
# 2  [{'code_index': '1', 'category': 'WC', 'subtyp...    30587
# 3  [{'code_index': '1', 'category': 'WC', 'subtyp...    88430
# 4  [{'code_index': '1', 'category': 'WC', 'subtyp...    70094

# %%
df['misuses'][0]
# Out:
# [{'code_index': '1',
#   'category': 'WC',
#   'subtype': 'Weak Cryptography',
#   'confidence': 0.9500000000000001,
#   'evidence': 'var hash = sha512(salt + password);',
#   'rationale': 'The use of a simple hash function with a salt without proper rotation or storage is a weak cryptographic practice.  The salt is not rotated, making it vulnerable to reuse.'},
#  {'code_index': '2',
#   'category': 'WC',
#   'subtype': 'Weak Cryptography',
#   'confidence': 0.9500000000000001,
#   'evidence': 'var hash = sha512(salt + password); for (i = 0; i &lt; 1000; i++) { hash = sha512(hash); }',
#   'rationale': 'The code repeatedly calculates the hash with the same salt and password, creating a predictable state. This increases the risk of replay attacks.'}]
