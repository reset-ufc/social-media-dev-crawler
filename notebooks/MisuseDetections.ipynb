# %%
import pandas as pd

# %%
df = pd.read_json('C:\K\social-media-dev-crawler\data\llm_inference\misuse_cases_codes.json')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\RESET Lab\AppData\Local\Temp\ipykernel_9568\3563995760.py:1: SyntaxWarning: invalid escape sequence '\K'
#   df = pd.read_json('C:\K\social-media-dev-crawler\data\llm_inference\misuse_cases_codes.json')

# %%
df.head()
# Out:
#    has_misuse                                            summary  \
# 0        True  The code utilizes a weak, deprecated ChaCha20-...
# 1        True  The code utilizes a weak cryptographic algorit...
# 2        True  The code exhibits several potential weaknesses...
# 3        True  The discussion reveals several potential vulne...
# 4        True  The code presents a weak RSA private key, usin...
#
#                                              misuses  post_id
# 0  [{'code_index': '1', 'category': 'WC', 'subtyp...    70094
# 1  [{'code_index': '1', 'category': 'WC', 'subtyp...    55014
# 2  [{'code_index': '1', 'category': 'WC', 'subtyp...     8687
# 3  [{'code_index': '1', 'category': 'WC', 'subtyp...     8695
# 4  [{'code_index': '1', 'category': 'WC', 'subtyp...    12378

# %%
df[df['post_id'] == 8687]
# Out:
#    has_misuse                                            summary  \
# 2        True  The code exhibits several potential weaknesses...
#
#                                              misuses  post_id
# 2  [{'code_index': '1', 'category': 'WC', 'subtyp...     8687
