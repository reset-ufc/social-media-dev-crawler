# %%
import pandas as pd

# %%
df = pd.read_csv('C:\K\social-media-dev-crawler\data\preprocessed_full_posts.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\RESET Lab\AppData\Local\Temp\ipykernel_9724\3090596.py:1: SyntaxWarning: invalid escape sequence '\K'
#   df = pd.read_csv('C:\K\social-media-dev-crawler\data\preprocessed_full_posts.csv')
# C:\Users\RESET Lab\AppData\Local\Temp\ipykernel_9724\3090596.py:1: DtypeWarning: Columns (1,6,7,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:\K\social-media-dev-crawler\data\preprocessed_full_posts.csv')
#   site_alias                                      tags  question_id  \
# 0     crypto                                       tls        55098
# 1     crypto  authenticated-encryption;poly1305;chacha        66450
# 2     crypto  authenticated-encryption;poly1305;chacha        58036
# 3     crypto                  hmac;passwords;sha-1;md5        57666
# 4     crypto                                   tls;rc4          853
#
#    accepted_answer_id  answer_count         creation_date  \
# 0                 NaN           1.0  2018/01/29, 09:21:12
# 1             67267.0           2.0  2019/01/13, 06:14:34
# 2             58038.0           1.0  2018/04/02, 11:29:54
# 3             57668.0           1.0  2018/03/20, 22:32:12
# 4                 NaN           7.0  2011/09/29, 05:30:51
#
#      last_activity_date        last_edit_date  owner_id  score  view_count  \
# 0  2018/01/30, 10:27:40  2021/10/07, 07:24:50   55511.0      1       159.0
# 1  2019/02/13, 13:28:19  2021/10/07, 07:34:52   56901.0      3      3234.0
# 2  2018/04/02, 13:38:56  2021/10/07, 07:59:29   57101.0      2       354.0
# 3  2018/03/21, 00:28:18  2021/10/07, 07:34:52   57101.0      2        61.0
# 4  2014/08/26, 20:58:28  2011/09/29, 08:05:21      38.0     52     33088.0
#
#                                                title  \
# 0  Tls 1.3 ClientHello legacy_session_id as zero ...
# 1               Understanding ChaCha20-Poly1305 AEAD
# 2  Should I include the ciphertext length in an A...
# 3  Expanding truly random key into printable pass...
# 4  Google is using RC4, but isn't RC4 considered ...
#
#                                                 body  \
# 0  Looking at tls 1.3 draft 23: https://datatrack...
# 1  In the AEAD scheme described in https://www.rf...
# 2  I want to construct a time-limited authorizati...
# 3  The STUN network protocol defines its client a...
# 4  Why is Google using RC4 for their HTTPS/SSL?\n...
#
#                           site     id  type
# 0  crypto.stackexchange.com.7z  55098  post
# 1  crypto.stackexchange.com.7z  66450  post
# 2  crypto.stackexchange.com.7z  58036  post
# 3  crypto.stackexchange.com.7z  57666  post
# 4  crypto.stackexchange.com.7z    853  post

# %%
full_post = df[df['question_id'] == 66450]
full_post
# Out:
#       site_alias                                      tags  question_id  \
# 1         crypto  authenticated-encryption;poly1305;chacha        66450
# 25469     crypto                                       NaN        66450
# 34069     crypto                                       NaN        66450
#
#        accepted_answer_id  answer_count            creation_date  \
# 1                 67267.0           2.0     2019/01/13, 06:14:34
# 25469                 NaN           NaN  2019-02-13T13:28:19.613
# 34069                 NaN           NaN  2019-01-13T12:06:24.473
#
#          last_activity_date        last_edit_date  owner_id  score  \
# 1      2019/02/13, 13:28:19  2021/10/07, 07:34:52   56901.0      3
# 25469                   NaN                   NaN    1172.0      4
# 34069                   NaN                   NaN   36960.0      1
#
#        view_count                                 title  \
# 1          3234.0  Understanding ChaCha20-Poly1305 AEAD
# 25469         NaN                                   NaN
# 34069         NaN                                   NaN
#
#                                                     body  \
# 1      In the AEAD scheme described in https://www.rf...
# 25469  It is the authentication - which uses Poly-130...
# 34069  One advantage it provides, is that you can cal...
#
#                               site     id    type
# 1      crypto.stackexchange.com.7z  66450    post
# 25469  crypto.stackexchange.com.7z  67267  answer
# 34069  crypto.stackexchange.com.7z  66456  answer
