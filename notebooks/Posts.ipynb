# %%
import pandas as pd

# %%
df = pd.read_csv('C:\K\social-media-dev-crawler\data\preprocessed_full_posts.csv')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\RESET Lab\AppData\Local\Temp\ipykernel_23352\3090596.py:1: SyntaxWarning: invalid escape sequence '\K'
#   df = pd.read_csv('C:\K\social-media-dev-crawler\data\preprocessed_full_posts.csv')
#                     site_alias  \
# 0  crypto.stackexchange.com.7z
# 1  crypto.stackexchange.com.7z
# 2  crypto.stackexchange.com.7z
# 3  crypto.stackexchange.com.7z
# 4  crypto.stackexchange.com.7z
#
#                                                 tags  question_id  \
# 0  cryptanalysis;elliptic-curves;dsa;signature;pu...        71764
# 1                encryption;keys;key-derivation;hash         2523
# 2                     secure-storage;keys;public-key        35530
# 3  block-cipher;algorithm-design;commutative-encr...         6573
# 4                      cryptanalysis;file-encryption        72384
#
#    accepted_answer_id  answer_count            creation_date  \
# ...

# %%
df[df['question_id'] == 71764]
# Out:
#                        site_alias  \
# 0     crypto.stackexchange.com.7z
# 272                        crypto
# 623                        crypto
# 1472                       crypto
# 1474                       crypto
# 1475                       crypto
# 1476                       crypto
# 1478                       crypto
# 1479                       crypto
#
#                                                    tags  question_id  \
# 0     cryptanalysis;elliptic-curves;dsa;signature;pu...        71764
# 272                                                 NaN        71764
# 623                                                 NaN        71764
# 1472                                                NaN        71764
# 1474                                                NaN        71764
# 1475                                                NaN        71764
# 1476                                                NaN        71764
# ...
