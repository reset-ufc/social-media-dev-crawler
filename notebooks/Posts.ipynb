# %%
import pandas as pd

# %%
df = pd.read_xml('C:\K\social-media-dev-crawler\Extraidos dump\stackapps.com\crypto.meta.stackexchange.com\Posts.xml',xpath='//row')
df.head()
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# <>:1: SyntaxWarning: invalid escape sequence '\K'
# C:\Users\RESET Lab\AppData\Local\Temp\ipykernel_9412\1357480996.py:1: SyntaxWarning: invalid escape sequence '\K'
#   df = pd.read_xml('C:\K\social-media-dev-crawler\Extraidos dump\stackapps.com\crypto.meta.stackexchange.com\Posts.xml',xpath='//row')
#      Id  PostTypeId             CreationDate  Score  ViewCount  \
# 0    52           1  2011-07-25T20:16:04.240      4       71.0
# 1   119           1  2011-11-30T10:51:22.803      2       29.0
# 2   141           1  2012-03-05T22:46:43.990      6       60.0
# 3  1166           4  2019-01-08T18:27:57.993      0        NaN
# 4    58           1  2011-08-01T12:09:57.447      2       82.0
#
#                                                 Body OwnerDisplayName  \
# 0  <p>Ok so as has been raised a couple of times,...           user46
# 1  <p>So, after <a href="http://chat.stackexchang...           user46
# ...

# %%
df['Body'][2]at
# Out:
# '<p>Then <a href="http://chat.stackexchange.com/rooms/2691/the-assembly">the assembly</a> is the room you need.</p>\n\n<p>As some of you may or may not know, moderators have a room that\'s hidden from public eyes. There\'s several reasons for this:</p>\n\n<ul>\n<li>We need, sometimes, to discuss private user details.</li>\n<li>We sometimes get heads up on decisions that might be pulled</li>\n</ul>\n\n<p>etc. You get the idea. However, a <em>lot</em> of stuff can and should be discussed in public.</p>\n\n<p>This is where the assembly comes in. This is a new room where moderators from many different sites on the network can come together to discuss things we can discuss in the open - migrations, how to handle certain types of questions etc.</p>\n\n<p>Anyone with any constructive comments, or who simply wishes to ask a few questions, is welcome to join us. I will not always be there, but mods from other sites will.</p>\n\n<p>What to expect:</p>\n\n<ul>\n<li>Moderators will always be the
# ...
