# %%
import pandas as pd

# %%
df = pd.read_xml('../dump/stackexchange_20240930/stackexchange_20240930/crypto.meta.stackexchange.com/Posts.xml')
df.head()
# Out:
#      Id  PostTypeId             CreationDate  Score  ViewCount  \
# 0    52           1  2011-07-25T20:16:04.240      4       71.0
# 1   119           1  2011-11-30T10:51:22.803      2       29.0
# 2   141           1  2012-03-05T22:46:43.990      6       59.0
# 3  1166           4  2019-01-08T18:27:57.993      0        NaN
# 4    58           1  2011-08-01T12:09:57.447      2       82.0
#
#                                                 Body OwnerDisplayName  \
# 0  <p>Ok so as has been raised a couple of times,...           user46
# 1  <p>So, after <a href="http://chat.stackexchang...           user46
# 2  <p>Then <a href="http://chat.stackexchange.com...           user46
# 3  Unanswered questions are those questions which...        user63532
# 4  <p>On the <a href="http://area51.stackexchange...           user93
#
#           LastActivityDate                                              Title  \
# 0  2011-07-28T19:19:40.417           Can we invite users to the private beta?
# ...

# %%
df = pd.read_xml('../dump/stackexchange_20240930/stackexchange_20240930/crypto.meta.stackexchange.com/Posts.xml',
                 xpath='//row')
df.head()
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 132
#      Id  PostTypeId             CreationDate  Score  ViewCount  \
# 0    52           1  2011-07-25T20:16:04.240      4       71.0
# 1   119           1  2011-11-30T10:51:22.803      2       29.0
# 2   141           1  2012-03-05T22:46:43.990      6       59.0
# 3  1166           4  2019-01-08T18:27:57.993      0        NaN
# 4    58           1  2011-08-01T12:09:57.447      2       82.0
#
#                                                 Body OwnerDisplayName  \
# 0  <p>Ok so as has been raised a couple of times,...           user46
# 1  <p>So, after <a href="http://chat.stackexchang...           user46
# 2  <p>Then <a href="http://chat.stackexchange.com...           user46
# 3  Unanswered questions are those questions which...        user63532
# 4  <p>On the <a href="http://area51.stackexchange...           user93
#
# ...
